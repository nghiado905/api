# %%
import sys
import random
import itertools

import a_lib as ace
import a1 as hf
import pandas as pd
import requests
import plotly.express as px

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_T6kJAEM3keY1nfdszKqurDa3ggB6

# %%
datasets_df = hf.get_datasets(s)
datasets_df
# Out:
# GLB
# TOP3000
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 82  shortinterest6              SmartHoldings Model
# 83  shortinterest7              Short Selling Model
# 84   socialmedia12        Sentiment Data for Equity
# 85    socialmedia5           Lexical Breakdown Data
# 86           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 82  This dataset is a global stock selection model...
# 83  The dataset combines features obtained from sh...
# 84  This dataset provides sentiment data with diff...
# 85  Sentiment scores derived from social media. So...
# 86                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 82  {'id': 'shortinterest', 'name': 'Short Interest'}
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84      {'id': 'socialmedia', 'name': 'Social Media'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  TOP3000
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  TOP3000
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  TOP3000
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  TOP3000
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  TOP3000
# ..                                                ...    ...    ...      ...
# 82  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  TOP3000
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  TOP3000
# 84  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  TOP3000
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  TOP3000
# 86  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  TOP3000
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         47         216         197     []
# 1     0.5186     None         3.0         71         364         926     []
# 2     0.9929     None         2.0        115         747         288     []
# 3     0.9013     None         2.0         60         434          42     []
# 4     0.4375     None         3.0         15          26          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 82    0.9711     None         2.0         23         131          11     []
# 83    1.0000     None         2.0         23         182          16     []
# 84    0.6731     None         3.0          2           2           2     []
# 85    0.3753     None         5.0          1           1          12     []
# 86    1.0000     None         4.0          1           8           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 82                                                 []
# 83  [{'title': 'Research Paper 04: Strategic Rebal...
# 84  [{'title': 'Research Paper 01: Textual Sentime...
# 85                                                 []
# 86                                                 []
#
# [87 rows x 16 columns]

# %%
selected_datasets_df = datasets_df[ 
    (datasets_df['region'] == 'GLB')
    ]
selected_datasets_df
# Out:
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 82  shortinterest6              SmartHoldings Model
# 83  shortinterest7              Short Selling Model
# 84   socialmedia12        Sentiment Data for Equity
# 85    socialmedia5           Lexical Breakdown Data
# 86           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 82  This dataset is a global stock selection model...
# 83  The dataset combines features obtained from sh...
# 84  This dataset provides sentiment data with diff...
# 85  Sentiment scores derived from social media. So...
# 86                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 82  {'id': 'shortinterest', 'name': 'Short Interest'}
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84      {'id': 'socialmedia', 'name': 'Social Media'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  TOP3000
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  TOP3000
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  TOP3000
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  TOP3000
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  TOP3000
# ..                                                ...    ...    ...      ...
# 82  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  TOP3000
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  TOP3000
# 84  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  TOP3000
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  TOP3000
# 86  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  TOP3000
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         47         216         197     []
# 1     0.5186     None         3.0         71         364         926     []
# 2     0.9929     None         2.0        115         747         288     []
# 3     0.9013     None         2.0         60         434          42     []
# 4     0.4375     None         3.0         15          26          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 82    0.9711     None         2.0         23         131          11     []
# 83    1.0000     None         2.0         23         182          16     []
# 84    0.6731     None         3.0          2           2           2     []
# 85    0.3753     None         5.0          1           1          12     []
# 86    1.0000     None         4.0          1           8           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 82                                                 []
# 83  [{'title': 'Research Paper 04: Strategic Rebal...
# 84  [{'title': 'Research Paper 01: Textual Sentime...
# 85                                                 []
# 86                                                 []
#
# [87 rows x 16 columns]

# %%
for i in range(len(selected_datasets_df.id.values)):
    dataset_id = selected_datasets_df.id.values.tolist()[i]# create a list of selected datasets ids, our list has only one element
    datafields_df = hf.get_datafields(s, dataset_id=dataset_id)
    datafields_df = datafields_df[
        datafields_df['type'] == 'MATRIX'
    ]
    
    chat_gpt = datafields_df [['id','description']]
    chat_gpt.to_csv(f'D:/Private/CODE/MY_API/data/GLB/{dataset_id}.csv')
